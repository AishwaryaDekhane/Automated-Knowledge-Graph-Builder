# %%
# web_scraping.py

import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_html(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    return response.text

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    fpga_data = []
    for fpga in soup.find_all('div', class_='fpga-spec'):
        model = fpga.find('h2').text
        ram = fpga.find('span', class_='ram').text
        logic_elements = fpga.find('span', class_='logic-elements').text
        fpga_data.append({'model': model, 'ram': ram, 'logic_elements': logic_elements})
    return fpga_data

def main():
    url = "https://www.example.com/altera-fpgas"
    html = fetch_html(url)
    data = parse_html(html)
    df = pd.DataFrame(data)
    df.to_csv('fpgas.csv', index=False)
    print(df)

if __name__ == "__main__":
    main()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pip install neo4j pandas
# Out:
# Collecting neo4j
#   Downloading neo4j-5.22.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pandas in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: pytz in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from neo4j) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading neo4j-5.22.0-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.5/293.5 kB 594.3 kB/s eta 0:00:0000:010:01m
# Installing collected packages: neo4j
# Successfully installed neo4j-5.22.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (24.0)
# Collecting pip
#   Downloading pip-24.1.2-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.1.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-24.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# knowledge_graph.py

from neo4j import GraphDatabase
import pandas as pd

class KnowledgeGraph:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def create_node(self, tx, label, properties):
        query = f"CREATE (n:{label} {{"
        query += ", ".join([f"{key}: ${key}" for key in properties.keys()])
        query += "})"
        tx.run(query, **properties)

    def create_relationship(self, tx, from_node, to_node, relationship_type, properties):
        query = f"""
        MATCH (a:{from_node['label']}), (b:{to_node['label']})
        WHERE a.{from_node['key']} = $from_value AND b.{to_node['key']} = $to_value
        CREATE (a)-[r:{relationship_type} {{"""
        query += ", ".join([f"{key}: ${key}" for key in properties.keys()])
        query += f"}}]->(b)"
        tx.run(query, from_value=from_node['value'], to_value=to_node['value'], **properties)

    def build_graph(self, data):
        with self.driver.session() as session:
            for _, row in data.iterrows():
                session.write_transaction(self.create_node, "FPGA", {"model": row['model']})
                session.write_transaction(self.create_node, "RAM", {"size": row['ram']})
                session.write_transaction(self.create_node, "LogicElement", {"count": row['logic_elements']})
                session.write_transaction(
                    self.create_relationship,
                    {"label": "FPGA", "key": "model", "value": row['model']},
                    {"label": "RAM", "key": "size", "value": row['ram']},
                    "HAS_RAM", {}
                )
                session.write_transaction(
                    self.create_relationship,
                    {"label": "FPGA", "key": "model", "value": row['model']},
                    {"label": "LogicElement", "key": "count", "value": row['logic_elements']},
                    "HAS_LOGIC_ELEMENTS", {}
                )

def main():
    uri = "bolt://localhost:7687"
    user = "neo4j"
    password = "password"
    kg = KnowledgeGraph(uri, user, password)
    
    df = pd.read_csv('fpgas.csv')
    kg.build_graph(df)
    kg.close()

if __name__ == "__main__":
    main()
# Out:
# /var/folders/tc/p09j7ll56zbbhd266ds5wqh40000gn/T/ipykernel_49802/1650237129.py:32: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(self.create_node, "FPGA", {"model": row['model']})
# Transaction failed and will be retried in 1.027309238867623s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 1.72597411822719s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 4.174043524216788s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 7.692070803373481s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 17.206129804256854s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:528, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     527 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 528 s.connect(resolved_address)
#     529 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:690, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     689 try:
# --> 690     s = BoltSocket._connect(resolved_address, tcp_timeout,
#     691                             keep_alive)
#     692     s = BoltSocket._secure(s, resolved_address._host_name,
#     693                            ssl_context)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:546, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     545 if isinstance(error, OSError):
# --> 546     raise ServiceUnavailable(
#     547         "Failed to establish connection to {!r} (reason {})"
#     548         .format(resolved_address, error)
#     549     ) from error
#     550 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[5], line 59
#      56     kg.close()
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[5], line 55, in main()
#      52 kg = KnowledgeGraph(uri, user, password)
#      54 df = pd.read_csv('fpgas.csv')
# ---> 55 kg.build_graph(df)
#      56 kg.close()
#
# Cell In[5], line 32, in KnowledgeGraph.build_graph(self, data)
#      30 with self.driver.session() as session:
#      31     for _, row in data.iterrows():
# ---> 32         session.write_transaction(self.create_node, "FPGA", {"model": row['model']})
#      33         session.write_transaction(self.create_node, "RAM", {"size": row['ram']})
#      34         session.write_transaction(self.create_node, "LogicElement", {"count": row['logic_elements']})
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_meta.py:221, in _make_warning_decorator.<locals>.decorator.<locals>.inner(*args, **kwargs)
#     218 @wraps(f)
#     219 def inner(*args, **kwargs):
#     220     warning_func(message, stack_level=2)
# --> 221     return f(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:799, in Session.write_transaction(self, transaction_function, *args, **kwargs)
#     765 @deprecated("write_transaction has been renamed to execute_write")
#     766 @NonConcurrentMethodChecker.non_concurrent_method
#     767 def write_transaction(
#    (...)
#     772     *args: _P.args,  **kwargs: _P.kwargs
#     773 ) -> _R:
#     774     """Execute a unit of work in a managed write transaction.
#     775
#     776     .. note::
#    (...)
#     797         Method was renamed to :meth:`.execute_write`.
#     798     """
# --> 799     return self._run_transaction(
#     800         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     801         transaction_function, args, kwargs
#     802     )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:590, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     587         raise
#     589 if errors:
# --> 590     raise errors[-1]
#     591 else:
#     592     raise ServiceUnavailable("Transaction failed")
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:545, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     543 while True:
#     544     try:
# --> 545         self._open_transaction(
#     546             tx_cls=ManagedTransaction,
#     547             api=None if telemetry_sent else api,
#     548             access_mode=access_mode, metadata=metadata,
#     549             timeout=timeout, api_success_cb=api_success_cb,
#     550         )
#     551         assert isinstance(self._transaction, ManagedTransaction)
#     552         tx = self._transaction
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:424, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     413 def _open_transaction(
#     414     self,
#     415     *,
#    (...)
#     422     api_success_cb: t.Optional[t.Callable[[dict], None]] = None,
#     423 ) -> None:
# --> 424     self._connect(access_mode=access_mode)
#     425     assert self._connection is not None
#     426     if api is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/workspace.py:182, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
# --> 182 self._connection = self._pool.acquire(**acquire_kwargs_)
#     183 self._connection_access_mode = access_mode
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:526, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     523 log.debug("[#0000]  _: <POOL> acquire direct connection, "
#     524           "access_mode=%r, database=%r", access_mode, database)
#     525 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 526 return self._acquire(
#     527     self.address, auth, deadline, liveness_check_timeout
#     528 )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:500, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     499 def opener(addr, auth_manager, deadline):
# --> 500     return Bolt.open(
#     501         addr, auth_manager=auth_manager, deadline=deadline,
#     502         routing_context=None, pool_config=pool_config
#     503     )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:403, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     399 if deadline is None:
#     400     deadline = Deadline(None)
#     402 s, protocol_version, handshake, data = \
# --> 403     BoltSocket.connect(
#     404         address,
#     405         tcp_timeout=pool_config.connection_timeout,
#     406         deadline=deadline,
#     407         custom_resolver=pool_config.resolver,
#     408         ssl_context=pool_config.get_ssl_context(),
#     409         keep_alive=pool_config.keep_alive,
#     410     )
#     412 pool_config.protocol_version = protocol_version
#     414 # Carry out Bolt subclass imports locally to avoid circular dependency
#     415 # issues.
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:718, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     713     raise ServiceUnavailable(
#     714         "Couldn't connect to %s (resolved to %s)" % (
#     715             str(address), tuple(map(str, resolved_addresses)))
#     716     )
#     717 else:
# --> 718     raise ServiceUnavailable(
#     719         "Couldn't connect to %s (resolved to %s):\n%s" % (
#     720             str(address), tuple(map(str, resolved_addresses)),
#     721             "\n".join(map(str, errors))
#     722         )
#     723     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused)

# %%
neo4j start
# Out:
#   Cell In[6], line 1
#     neo4j start
#           ^
# SyntaxError: invalid syntax

# %%
neo4j status
# Out:
#   Cell In[7], line 1
#     neo4j status
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from neo4j import GraphDatabase

class KnowledgeGraph:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def create_entity(self, tx, label, properties):
        query = f"CREATE (n:{label} {{"
        query += ", ".join([f"{key}: ${key}" for key in properties.keys()])
        query += "})"
        tx.run(query, **properties)

    def create_relationship(self, tx, from_label, from_properties, to_label, to_properties, relationship_type):
        query = f"""
        MATCH (a:{from_label}), (b:{to_label})
        WHERE a.{from_properties['key']} = $from_value AND b.{to_properties['key']} = $to_value
        CREATE (a)-[r:{relationship_type}]->(b)
        """
        tx.run(query, from_value=from_properties['value'], to_value=to_properties['value'])

    def build_graph(self, df):
        with self.driver.session() as session:
            for index, row in df.iterrows():
                session.execute_write(self.create_entity, "FPGA", {"model": row['model']})
                session.execute_write(self.create_entity, "RAM", {"size": row['RAM_size']})
                session.execute_write(self.create_entity, "LogicElements", {"count": row['logic_elements']})
                session.execute_write(
                    self.create_relationship, 
                    "FPGA", {"key": "model", "value": row['model']}, 
                    "RAM", {"key": "size", "value": row['RAM_size']}, 
                    "HAS_RAM"
                )
                session.execute_write(
                    self.create_relationship, 
                    "FPGA", {"key": "model", "value": row['model']}, 
                    "LogicElements", {"key": "count", "value": row['logic_elements']}, 
                    "HAS_LOGIC_ELEMENTS"
                )

def main():
    uri = "bolt://localhost:7687"
    user = "neo4j"
    password = "password"
    kg = KnowledgeGraph(uri, user, password)

    # Ensure the CSV file exists and has content
    try:
        df = pd.read_csv('fpgas.csv')
        kg.build_graph(df)
    except pd.errors.EmptyDataError:
        print("The CSV file is empty or does not contain any data.")

    kg.close()

if __name__ == "__main__":
    main()
# Out:
# Transaction failed and will be retried in 1.1488412997142425s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 1.8796966157233272s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 4.193654113382349s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 8.962522615727252s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 15.278082581508095s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:528, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     527 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 528 s.connect(resolved_address)
#     529 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:690, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     689 try:
# --> 690     s = BoltSocket._connect(resolved_address, tcp_timeout,
#     691                             keep_alive)
#     692     s = BoltSocket._secure(s, resolved_address._host_name,
#     693                            ssl_context)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:546, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     545 if isinstance(error, OSError):
# --> 546     raise ServiceUnavailable(
#     547         "Failed to establish connection to {!r} (reason {})"
#     548         .format(resolved_address, error)
#     549     ) from error
#     550 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[8], line 61
#      58     kg.close()
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# Cell In[8], line 54, in main()
#      52 try:
#      53     df = pd.read_csv('fpgas.csv')
# ---> 54     kg.build_graph(df)
#      55 except pd.errors.EmptyDataError:
#      56     print("The CSV file is empty or does not contain any data.")
#
# Cell In[8], line 29, in KnowledgeGraph.build_graph(self, df)
#      27 with self.driver.session() as session:
#      28     for index, row in df.iterrows():
# ---> 29         session.execute_write(self.create_entity, "FPGA", {"model": row['model']})
#      30         session.execute_write(self.create_entity, "RAM", {"size": row['RAM_size']})
#      31         session.execute_write(self.create_entity, "LogicElements", {"count": row['logic_elements']})
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:759, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     708 @NonConcurrentMethodChecker.non_concurrent_method
#     709 def execute_write(
#     710     self,
#    (...)
#     714     *args: _P.args,  **kwargs: _P.kwargs
#     715 ) -> _R:
#     716     """Execute a unit of work in a managed write transaction.
#     717
#     718     .. note::
#    (...)
#     757     .. versionadded:: 5.0
#     758     """
# --> 759     return self._run_transaction(
#     760         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     761         transaction_function, args, kwargs
#     762     )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:590, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     587         raise
#     589 if errors:
# --> 590     raise errors[-1]
#     591 else:
#     592     raise ServiceUnavailable("Transaction failed")
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:545, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     543 while True:
#     544     try:
# --> 545         self._open_transaction(
#     546             tx_cls=ManagedTransaction,
#     547             api=None if telemetry_sent else api,
#     548             access_mode=access_mode, metadata=metadata,
#     549             timeout=timeout, api_success_cb=api_success_cb,
#     550         )
#     551         assert isinstance(self._transaction, ManagedTransaction)
#     552         tx = self._transaction
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:424, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     413 def _open_transaction(
#     414     self,
#     415     *,
#    (...)
#     422     api_success_cb: t.Optional[t.Callable[[dict], None]] = None,
#     423 ) -> None:
# --> 424     self._connect(access_mode=access_mode)
#     425     assert self._connection is not None
#     426     if api is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/workspace.py:182, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
# --> 182 self._connection = self._pool.acquire(**acquire_kwargs_)
#     183 self._connection_access_mode = access_mode
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:526, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     523 log.debug("[#0000]  _: <POOL> acquire direct connection, "
#     524           "access_mode=%r, database=%r", access_mode, database)
#     525 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 526 return self._acquire(
#     527     self.address, auth, deadline, liveness_check_timeout
#     528 )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:500, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     499 def opener(addr, auth_manager, deadline):
# --> 500     return Bolt.open(
#     501         addr, auth_manager=auth_manager, deadline=deadline,
#     502         routing_context=None, pool_config=pool_config
#     503     )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:403, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     399 if deadline is None:
#     400     deadline = Deadline(None)
#     402 s, protocol_version, handshake, data = \
# --> 403     BoltSocket.connect(
#     404         address,
#     405         tcp_timeout=pool_config.connection_timeout,
#     406         deadline=deadline,
#     407         custom_resolver=pool_config.resolver,
#     408         ssl_context=pool_config.get_ssl_context(),
#     409         keep_alive=pool_config.keep_alive,
#     410     )
#     412 pool_config.protocol_version = protocol_version
#     414 # Carry out Bolt subclass imports locally to avoid circular dependency
#     415 # issues.
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:718, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     713     raise ServiceUnavailable(
#     714         "Couldn't connect to %s (resolved to %s)" % (
#     715             str(address), tuple(map(str, resolved_addresses)))
#     716     )
#     717 else:
# --> 718     raise ServiceUnavailable(
#     719         "Couldn't connect to %s (resolved to %s):\n%s" % (
#     720             str(address), tuple(map(str, resolved_addresses)),
#     721             "\n".join(map(str, errors))
#     722         )
#     723     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused)

# %%
# Example for downloading Neo4j Community Edition 4.5.2 for macOS
wget https://neo4j.com/artifact.php?name=neo4j-community-4.5.2-unix.tar.gz -O neo4j.tar.gz
# Out:
#   Cell In[9], line 2
#     wget https://neo4j.com/artifact.php?name=neo4j-community-4.5.2-unix.tar.gz -O neo4j.tar.gz
#          ^
# SyntaxError: invalid syntax

# %%
wget https://neo4j.com/artifact.php?name=neo4j-community-4.5.2-unix.tar.gz -O neo4j.tar.gz
# Out:
#   Cell In[10], line 1
#     wget https://neo4j.com/artifact.php?name=neo4j-community-4.5.2-unix.tar.gz -O neo4j.tar.gz
#          ^
# SyntaxError: invalid syntax

# %%
# web_scraping.py

import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_html(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    return response.text

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    fpga_data = []
    for fpga in soup.find_all('div', class_='fpga-spec'):
        model = fpga.find('h2').text
        ram = fpga.find('span', class_='ram').text
        logic_elements = fpga.find('span', class_='logic-elements').text
        fpga_data.append({'model': model, 'ram': ram, 'logic_elements': logic_elements})
    return fpga_data

def main():
    url = "https://www.example.com/altera-fpgas"
    html = fetch_html(url)
    data = parse_html(html)
    df = pd.DataFrame(data)
    df.to_csv('fpgas.csv', index=False)
    print(df)

if __name__ == "__main__":
    main()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pip install neo4j pandas
# Out:
# Requirement already satisfied: neo4j in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (5.22.0)
# Requirement already satisfied: pandas in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: pytz in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from neo4j) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# knowledge_graph.py

from neo4j import GraphDatabase
import pandas as pd

class KnowledgeGraph:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def create_node(self, tx, label, properties):
        query = f"CREATE (n:{label} {{"
        query += ", ".join([f"{key}: ${key}" for key in properties.keys()])
        query += "})"
        tx.run(query, **properties)

    def create_relationship(self, tx, from_node, to_node, relationship_type, properties):
        query = f"""
        MATCH (a:{from_node['label']}), (b:{to_node['label']})
        WHERE a.{from_node['key']} = $from_value AND b.{to_node['key']} = $to_value
        CREATE (a)-[r:{relationship_type} {{"""
        query += ", ".join([f"{key}: ${key}" for key in properties.keys()])
        query += f"}}]->(b)"
        tx.run(query, from_value=from_node['value'], to_value=to_node['value'], **properties)

    def build_graph(self, data):
        with self.driver.session() as session:
            for _, row in data.iterrows():
                session.write_transaction(self.create_node, "FPGA", {"model": row['model']})
                session.write_transaction(self.create_node, "RAM", {"size": row['ram']})
                session.write_transaction(self.create_node, "LogicElement", {"count": row['logic_elements']})
                session.write_transaction(
                    self.create_relationship,
                    {"label": "FPGA", "key": "model", "value": row['model']},
                    {"label": "RAM", "key": "size", "value": row['ram']},
                    "HAS_RAM", {}
                )
                session.write_transaction(
                    self.create_relationship,
                    {"label": "FPGA", "key": "model", "value": row['model']},
                    {"label": "LogicElement", "key": "count", "value": row['logic_elements']},
                    "HAS_LOGIC_ELEMENTS", {}
                )

def main():
    uri = "bolt://localhost:7687"
    user = "neo4j"
    password = "password"
    kg = KnowledgeGraph(uri, user, password)
    
    df = pd.read_csv('fpgas.csv')
    kg.build_graph(df)
    kg.close()

if __name__ == "__main__":
    main()
# Out:
# /var/folders/tc/p09j7ll56zbbhd266ds5wqh40000gn/T/ipykernel_49802/931545028.py:32: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(self.create_node, "FPGA", {"model": row['model']})
# Transaction failed and will be retried in 1.0641245872124314s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 2.1889157889983s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 4.365143840213662s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 8.941451453285914s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 12.929164027186456s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# Transaction failed and will be retried in 30.178362732977757s (Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused))
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:528, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     527 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 528 s.connect(resolved_address)
#     529 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:690, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     689 try:
# --> 690     s = BoltSocket._connect(resolved_address, tcp_timeout,
#     691                             keep_alive)
#     692     s = BoltSocket._secure(s, resolved_address._host_name,
#     693                            ssl_context)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:546, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     545 if isinstance(error, OSError):
# --> 546     raise ServiceUnavailable(
#     547         "Failed to establish connection to {!r} (reason {})"
#     548         .format(resolved_address, error)
#     549     ) from error
#     550 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[14], line 59
#      56     kg.close()
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[14], line 55, in main()
#      52 kg = KnowledgeGraph(uri, user, password)
#      54 df = pd.read_csv('fpgas.csv')
# ---> 55 kg.build_graph(df)
#      56 kg.close()
#
# Cell In[14], line 32, in KnowledgeGraph.build_graph(self, data)
#      30 with self.driver.session() as session:
#      31     for _, row in data.iterrows():
# ---> 32         session.write_transaction(self.create_node, "FPGA", {"model": row['model']})
#      33         session.write_transaction(self.create_node, "RAM", {"size": row['ram']})
#      34         session.write_transaction(self.create_node, "LogicElement", {"count": row['logic_elements']})
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_meta.py:221, in _make_warning_decorator.<locals>.decorator.<locals>.inner(*args, **kwargs)
#     218 @wraps(f)
#     219 def inner(*args, **kwargs):
#     220     warning_func(message, stack_level=2)
# --> 221     return f(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:799, in Session.write_transaction(self, transaction_function, *args, **kwargs)
#     765 @deprecated("write_transaction has been renamed to execute_write")
#     766 @NonConcurrentMethodChecker.non_concurrent_method
#     767 def write_transaction(
#    (...)
#     772     *args: _P.args,  **kwargs: _P.kwargs
#     773 ) -> _R:
#     774     """Execute a unit of work in a managed write transaction.
#     775
#     776     .. note::
#    (...)
#     797         Method was renamed to :meth:`.execute_write`.
#     798     """
# --> 799     return self._run_transaction(
#     800         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     801         transaction_function, args, kwargs
#     802     )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:590, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     587         raise
#     589 if errors:
# --> 590     raise errors[-1]
#     591 else:
#     592     raise ServiceUnavailable("Transaction failed")
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:545, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     543 while True:
#     544     try:
# --> 545         self._open_transaction(
#     546             tx_cls=ManagedTransaction,
#     547             api=None if telemetry_sent else api,
#     548             access_mode=access_mode, metadata=metadata,
#     549             timeout=timeout, api_success_cb=api_success_cb,
#     550         )
#     551         assert isinstance(self._transaction, ManagedTransaction)
#     552         tx = self._transaction
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:424, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     413 def _open_transaction(
#     414     self,
#     415     *,
#    (...)
#     422     api_success_cb: t.Optional[t.Callable[[dict], None]] = None,
#     423 ) -> None:
# --> 424     self._connect(access_mode=access_mode)
#     425     assert self._connection is not None
#     426     if api is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/work/workspace.py:182, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
# --> 182 self._connection = self._pool.acquire(**acquire_kwargs_)
#     183 self._connection_access_mode = access_mode
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:526, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     523 log.debug("[#0000]  _: <POOL> acquire direct connection, "
#     524           "access_mode=%r, database=%r", access_mode, database)
#     525 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 526 return self._acquire(
#     527     self.address, auth, deadline, liveness_check_timeout
#     528 )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_pool.py:500, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     499 def opener(addr, auth_manager, deadline):
# --> 500     return Bolt.open(
#     501         addr, auth_manager=auth_manager, deadline=deadline,
#     502         routing_context=None, pool_config=pool_config
#     503     )
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_sync/io/_bolt.py:403, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     399 if deadline is None:
#     400     deadline = Deadline(None)
#     402 s, protocol_version, handshake, data = \
# --> 403     BoltSocket.connect(
#     404         address,
#     405         tcp_timeout=pool_config.connection_timeout,
#     406         deadline=deadline,
#     407         custom_resolver=pool_config.resolver,
#     408         ssl_context=pool_config.get_ssl_context(),
#     409         keep_alive=pool_config.keep_alive,
#     410     )
#     412 pool_config.protocol_version = protocol_version
#     414 # Carry out Bolt subclass imports locally to avoid circular dependency
#     415 # issues.
#
# File ~/anaconda3/lib/python3.11/site-packages/neo4j/_async_compat/network/_bolt_socket.py:718, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     713     raise ServiceUnavailable(
#     714         "Couldn't connect to %s (resolved to %s)" % (
#     715             str(address), tuple(map(str, resolved_addresses)))
#     716     )
#     717 else:
# --> 718     raise ServiceUnavailable(
#     719         "Couldn't connect to %s (resolved to %s):\n%s" % (
#     720             str(address), tuple(map(str, resolved_addresses)),
#     721             "\n".join(map(str, errors))
#     722         )
#     723     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 61] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 61] Connection refused)

# %%
pip install requests beautifulsoup4 scrapy pandas
# Out:
# Requirement already satisfied: requests in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: scrapy in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (2.8.0)
# Requirement already satisfied: pandas in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: Twisted>=18.9.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (41.0.3)
# Requirement already satisfied: cssselect>=0.9.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: parsel>=1.5.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (23.2.0)
# Requirement already satisfied: queuelib>=1.4.2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: service-identity>=18.1.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.21.0)
# Requirement already satisfied: zope.interface>=5.1.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: itemadapter>=0.1.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: setuptools in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (68.0.0)
# Requirement already satisfied: packaging in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (23.1)
# Requirement already satisfied: tldextract in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: lxml>=4.3.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: cffi>=1.12 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: six>=1.6.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=16.0.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (23.2.0)
# Requirement already satisfied: pyasn1-modules in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: constantly>=15.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (21.3.0)
# Requirement already satisfied: Automat>=0.8.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (20.2.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (4.11.0)
# Requirement already satisfied: requests-file>=1.4 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: pycparser in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_webpage(url):
    """Fetches the content of a webpage."""
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return None

def parse_page(html):
    """Parses the HTML content and extracts relevant information."""
    soup = BeautifulSoup(html, 'html.parser')

    # Example: Extract headers and descriptions
    headers = [header.get_text(strip=True) for header in soup.find_all('h2')]
    descriptions = [desc.get_text(strip=True) for desc in soup.find_all('p')]

    # Combine extracted data into a dictionary
    data = {
        "headers": headers,
        "descriptions": descriptions
    }
    return data

def save_to_csv(data):
    """Saves extracted data to a CSV file."""
    df = pd.DataFrame({
        'Header': data['headers'],
        'Description': data['descriptions']
    })
    df.to_csv('fpga_data.csv', index=False)

def main():
    url = 'https://www.intel.com/content/www/us/en/products/details/fpga.html'
    html = fetch_webpage(url)
    if html:
        data = parse_page(html)
        save_to_csv(data)
        print("Data has been saved to fpga_data.csv")

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 46
#      43         print("Data has been saved to fpga_data.csv")
#      45 if __name__ == '__main__':
# ---> 46     main()
#
# Cell In[16], line 42, in main()
#      40 if html:
#      41     data = parse_page(html)
# ---> 42     save_to_csv(data)
#      43     print("Data has been saved to fpga_data.csv")
#
# Cell In[16], line 31, in save_to_csv(data)
#      29 def save_to_csv(data):
#      30     """Saves extracted data to a CSV file."""
# ---> 31     df = pd.DataFrame({
#      32         'Header': data['headers'],
#      33         'Description': data['descriptions']
#      34     })
#      35     df.to_csv('fpga_data.csv', index=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_html(url):
    """Fetches HTML content from the specified URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        return response.text
    except requests.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return None

def parse_page(html):
    """Parses the HTML content and extracts relevant information."""
    soup = BeautifulSoup(html, 'html.parser')

    # Example: Extract headers and descriptions
    headers = [header.get_text(strip=True) for header in soup.find_all('h2')]
    descriptions = [desc.get_text(strip=True) for desc in soup.find_all('p')]

    # Debug: Print lengths of the lists
    print(f"Number of headers: {len(headers)}")
    print(f"Number of descriptions: {len(descriptions)}")

    # Ensure that headers and descriptions have the same length
    max_length = max(len(headers), len(descriptions))
    headers.extend([''] * (max_length - len(headers)))
    descriptions.extend([''] * (max_length - len(descriptions)))

    data = {
        "headers": headers,
        "descriptions": descriptions
    }
    return data

def save_to_csv(data):
    """Saves extracted data to a CSV file."""
    df = pd.DataFrame({
        'Header': data['headers'],
        'Description': data['descriptions']
    })
    df.to_csv('fpga_data.csv', index=False)
    print("Data has been saved to fpga_data.csv")

def main():
    url = 'https://www.intel.com/content/www/us/en/products/details/fpga.html'
    html = fetch_html(url)
    if html:
        data = parse_page(html)
        save_to_csv(data)

if __name__ == '__main__':
    main()
# Out:
# Number of headers: 7
# Number of descriptions: 39
# Data has been saved to fpga_data.csv

# %%
pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (2.8.0)
# Requirement already satisfied: Twisted>=18.9.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (41.0.3)
# Requirement already satisfied: cssselect>=0.9.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: parsel>=1.5.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (23.2.0)
# Requirement already satisfied: queuelib>=1.4.2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: service-identity>=18.1.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (1.21.0)
# Requirement already satisfied: zope.interface>=5.1.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: itemadapter>=0.1.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: setuptools in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (68.0.0)
# Requirement already satisfied: packaging in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (23.1)
# Requirement already satisfied: tldextract in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: lxml>=4.3.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: cffi>=1.12 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: six>=1.6.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=16.0.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (23.2.0)
# Requirement already satisfied: pyasn1-modules in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: constantly>=15.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (21.3.0)
# Requirement already satisfied: Automat>=0.8.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (20.2.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (4.11.0)
# Requirement already satisfied: idna in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (2.32.3)
# Requirement already satisfied: requests-file>=1.4 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: pycparser in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aishwaryadekhane/anaconda3/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import scrapy

class IntelFpgaSpider(scrapy.Spider):
    name = 'intel_fpga_spider'
    start_urls = ['https://www.intel.com/content/www/us/en/products/details/fpga.html']

    def parse(self, response):
        headers = response.css('h2::text').getall()
        descriptions = response.css('p::text').getall()

        # Debug: Print lengths of the lists
        self.log(f"Number of headers: {len(headers)}")
        self.log(f"Number of descriptions: {len(descriptions)}")

        # Ensure that headers and descriptions have the same length
        max_length = max(len(headers), len(descriptions))
        headers.extend([''] * (max_length - len(headers)))
        descriptions.extend([''] * (max_length - len(descriptions)))

        for header, description in zip(headers, descriptions):
            yield {
                'Header': header,
                'Description': description
            }

# %%
import scrapy

class IntelFpgaSpider(scrapy.Spider):
    name = 'intel_fpga_spider'
    
    def __init__(self, url=None, *args, **kwargs):
        super(IntelFpgaSpider, self).__init__(*args, **kwargs)
        self.start_urls = [url] if url else []

    def parse(self, response):
        headers = response.css('h2::text').getall()
        descriptions = response.css('p::text').getall()

        # Ensure that headers and descriptions have the same length
        max_length = max(len(headers), len(descriptions))
        headers.extend([''] * (max_length - len(headers)))
        descriptions.extend([''] * (max_length - len(descriptions)))

        for header, description in zip(headers, descriptions):
            yield {
                'Header': header,
                'Description': description
            }

# %%
scrapy crawl intel_fpga_spider -o fpga_data.csv -a url=https://www.intel.com/content/www/us/en/products/details/fpga.html
# Out:
#   Cell In[21], line 1
#     scrapy crawl intel_fpga_spider -o fpga_data.csv -a url=https://www.intel.com/content/www/us/en/products/details/fpga.html
#            ^
# SyntaxError: invalid syntax

# %%
scrapy crawl intel_fpga_spider -o fpga_data.csv -a url="https://www.intel.com/content/www/us/en/products/details/fpga.html"
# Out:
#   Cell In[22], line 1
#     scrapy crawl intel_fpga_spider -o fpga_data.csv -a url="https://www.intel.com/content/www/us/en/products/details/fpga.html"
#            ^
# SyntaxError: invalid syntax

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_html(url):
    """Fetches HTML content from the specified URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        return response.text
    except requests.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return None

def parse_page(html):
    """Parses the HTML content and extracts relevant information."""
    soup = BeautifulSoup(html, 'html.parser')

    # Example: Extract headers and descriptions
    headers = [header.get_text(strip=True) for header in soup.find_all('h2')]
    descriptions = [desc.get_text(strip=True) for desc in soup.find_all('p')]

    # Debug: Print lengths of the lists
    print(f"Number of headers: {len(headers)}")
    print(f"Number of descriptions: {len(descriptions)}")

    # Ensure that headers and descriptions have the same length
    max_length = max(len(headers), len(descriptions))
    headers.extend([''] * (max_length - len(headers)))
    descriptions.extend([''] * (max_length - len(descriptions)))

    data = {
        "headers": headers,
        "descriptions": descriptions
    }
    return data

def save_to_csv(data):
    """Saves extracted data to a CSV file."""
    df = pd.DataFrame({
        'Header': data['headers'],
        'Description': data['descriptions']
    })
    df.to_csv('fpga_data.csv', index=False)
    print("Data has been saved to fpga_data.csv")

def main():
    url = 'https://en.wikipedia.org/wiki/Altera'
    html = fetch_html(url)
    if html:
        data = parse_page(html)
        save_to_csv(data)

if __name__ == '__main__':
    main()
# Out:
# Number of headers: 6
# Number of descriptions: 19
# Data has been saved to fpga_data.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_html(url):
    """Fetches HTML content from the specified URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return None

def parse_page(html):
    """Parses the HTML content and extracts relevant information."""
    soup = BeautifulSoup(html, 'html.parser')
    headers = [header.get_text(strip=True) for header in soup.find_all('h2')]
    descriptions = [desc.get_text(strip=True) for desc in soup.find_all('p')]
    max_length = max(len(headers), len(descriptions))
    headers.extend([''] * (max_length - len(headers)))
    descriptions.extend([''] * (max_length - len(descriptions)))
    data = {
        "headers": headers,
        "descriptions": descriptions
    }
    return data

def save_to_csv(data, filename='data.csv'):
    """Saves extracted data to a CSV file."""
    df = pd.DataFrame({
        'Header': data['headers'],
        'Description': data['descriptions']
    })
    df.to_csv(filename, index=False)
    print(f"Data has been saved to {filename}")

def main():
    url = input("Enter the URL to scrape: ")
    html = fetch_html(url)
    if html:
        data = parse_page(html)
        save_to_csv(data)

if __name__ == '__main__':
    main()
